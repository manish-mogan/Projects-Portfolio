# %% [markdown]
# # Datasets
#
# This folder contains a small set of general-purpose datasets used for visualization and EDA examples.
#
# Data files live in `./`.

# %%
from pathlib import Path

import pandas as pd

data_dir = Path(".")
rows = []
for p in sorted(data_dir.iterdir()):
    if p.is_file():
        rows.append({
            "file": p.name,
            "bytes": p.stat().st_size,
            "ext": p.suffix.lower(),
        })

df = pd.DataFrame(rows).sort_values("file").reset_index(drop=True)
df
# Out:
#                     file     bytes     ext
# 0           Airports.csv     23867    .csv
# 1     Athlete Events.csv  41229571    .csv
# 2         Datasets.ipynb      3916  .ipynb
# 3           Diamonds.csv   2772143    .csv
# 4  Sample Superstore.xls   3364352    .xls
