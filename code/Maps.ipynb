# %%
# %pip install folium
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !ls -la
# Out:
# total 8248
# drwxrwxrwx+ 2 codespace codespace    4096 Oct 29 02:03  .
# drwxrwxrwx+ 4 codespace codespace    4096 Oct 29 02:03  ..
# -rw-rw-rw-  1 codespace codespace 1748311 Oct 29 00:56  Altair.ipynb
# -rw-rw-rw-  1 codespace codespace  563859 Oct 29 03:17 'Clean Cars Mitra.ipynb'
# -rw-rw-rw-  1 codespace codespace 4022730 Oct 29 00:57  DataVizIntro.ipynb
# -rw-rw-rw-  1 codespace codespace   26596 Oct 29 03:17  Data_Wrangling.ipynb
# -rw-rw-rw-  1 codespace codespace  258510 Oct 30 21:22  Maps.ipynb
# -rw-rw-rw-  1 codespace codespace   63669 Oct 29 03:18  Merge_Joins.ipynb
# -rw-rw-rw-  1 codespace codespace   65338 Oct 29 01:01  Numpy_Basics.ipynb
# -rw-rw-rw-  1 codespace codespace   64459 Oct 29 03:18  Pandas.ipynb
# -rw-rw-rw-  1 codespace codespace  262176 Oct 29 01:05  Plotly.ipynb
# -rw-rw-rw-  1 codespace codespace  461953 Oct 29 03:17  Spatial_Data.ipynb
# -rw-rw-rw-  1 codespace codespace  595662 Oct 29 03:17  Stat.ipynb
# ...

# %%
import pandas as pd
import numpy as np
import folium as fm
import matplotlib.pyplot as plt

# %%
#dispaly the world map

world_map = fm.Map()
#world_map

# %%
#coordinates of Austin
atx_lat = 30.2672
atx_long = -97.7431

# %%
atx_map = fm.Map([atx_lat, atx_long])

# Add a marker to the map
fm.Marker([atx_lat + 0.01, atx_long + 0.01], popup='Sample Location').add_to(atx_map)

# Display the map with the marker
#atx_map

# %%
#read the crime data of San Francisco
df = pd.read_csv('../data/SF_Crime_2016.csv')
df.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
df.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'PdId'],
#       dtype='object')

# %%
df.describe()
# Out:
#          IncidntNum              X              Y          PdId
# count  1.505000e+05  150500.000000  150500.000000  1.505000e+05
# mean   1.616440e+08    -122.423599      37.768921  1.616440e+13
# std    5.535976e+06       0.026210       0.023637  5.535976e+11
# min    1.135121e+07    -122.513642      37.707922  1.135121e+12
# 25%    1.603283e+08    -122.434036      37.756486  1.603283e+13
# 50%    1.606541e+08    -122.416903      37.775421  1.606541e+13
# 75%    1.609764e+08    -122.406605      37.785063  1.609764e+13
# max    9.910090e+08    -122.365565      37.819975  9.910090e+13

# %%
df.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# ...

# %%
df.tail()
# Out:
#         IncidntNum        Category  \
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 150495                                            BATTERY    Friday
# 150496                                      LOST PROPERTY    Friday
# 150497                            PETTY THEFT OF PROPERTY  Thursday
# 150498                            GRAND THEFT OF PROPERTY    Friday
# 150499  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...    Friday
#
#                           Date   Time PdDistrict Resolution  \
# 150495  12/30/2016 12:00:00 AM  21:01       PARK       NONE
# 150496  12/30/2016 12:00:00 AM  08:00    CENTRAL       NONE
# 150497  12/29/2016 12:00:00 AM  20:00    CENTRAL       NONE
# 150498  12/30/2016 12:00:00 AM  10:00    CENTRAL       NONE
# ...

# %%
limit = 100
df_crime = df.iloc[0:limit, :]

# define the latitude and longitude of San Francisco
sd_lat = 37.77
sd_long = -122.42

#create a map of San Francisco
sd_map = fm.Map([sd_lat, sd_long])
sd_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
#create a feature group

# %%
crimes = fm.map.FeatureGroup()

# %%
#lop through the 100 crimes and add to the feature group


#add pop-up text
for lat, long in zip (df_crime.Y, df_crime.X):
    crimes.add_child(
        fm.features.CircleMarker(
            [lat, long],
            radius = 5,
            color = 'yellow',
            fill_color = 'blue',
            fill_opacity = 0.6
            )
    )


latituDEs = list(df_crime.Y)
longituDEs = list(df_crime.X)
labels = list(df_crime.Category)

for lat, long, label in zip(latituDEs, longituDEs, labels):
    (
        fm.Marker(
            [lat, long],
            popup = label
        ).add_to(sd_map)
    )

sd_map.add_child(crimes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
