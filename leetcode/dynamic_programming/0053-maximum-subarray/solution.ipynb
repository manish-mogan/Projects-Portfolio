# %% [markdown]
# # 0053 — Maximum SubarrayLink: https://leetcode.com/problems/maximum-subarray/## SummaryFind the maximum possible sum of a non-empty contiguous subarray.

# %%
"""0053 — Maximum Subarray"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0053 — Maximum Subarray"""from __future__ import annotationsclass Solution:    pass```
