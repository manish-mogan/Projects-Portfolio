# %% [markdown]
# # 0198 — House RobberLink: https://leetcode.com/problems/house-robber/## SummaryGiven non-negative values in houses along a street, maximize stolen amount without robbing adjacent houses.

# %%
"""0198 — House Robber"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0198 — House Robber"""from __future__ import annotationsclass Solution:    pass```
