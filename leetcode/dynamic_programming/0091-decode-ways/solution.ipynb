# %% [markdown]
# # 0091 — Decode WaysLink: https://leetcode.com/problems/decode-ways/## SummaryGiven a digit string, count the number of ways to decode it into letters using 1→A through 26→Z.

# %%
"""0091 — Decode Ways"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0091 — Decode Ways"""from __future__ import annotationsclass Solution:    pass```
