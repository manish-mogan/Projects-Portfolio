# %% [markdown]
# # 0070 — Climbing StairsLink: https://leetcode.com/problems/climbing-stairs/## SummaryCount how many distinct ways you can climb to the top if you can take 1 or 2 steps at a time.

# %%
"""0070 — Climbing Stairs"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0070 — Climbing Stairs"""from __future__ import annotationsclass Solution:    pass```
