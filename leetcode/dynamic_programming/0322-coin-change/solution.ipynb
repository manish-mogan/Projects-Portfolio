# %% [markdown]
# # 0322 — Coin ChangeLink: https://leetcode.com/problems/coin-change/## SummaryGiven coin denominations and an amount, return the fewest coins needed to make that amount (or -1 if impossible).

# %%
"""0322 — Coin Change"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0322 — Coin Change"""from __future__ import annotationsclass Solution:    pass```
