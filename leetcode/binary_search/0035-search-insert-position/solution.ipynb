# %% [markdown]
# # 0035 — Search Insert PositionLink: https://leetcode.com/problems/search-insert-position/## SummaryReturn the index where a target should be inserted in a sorted array to keep it ordered.

# %%
"""0035 — Search Insert Position"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
