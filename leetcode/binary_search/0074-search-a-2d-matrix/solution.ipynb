# %% [markdown]
# # 0074 — Search a 2D MatrixLink: https://leetcode.com/problems/search-a-2d-matrix/## SummaryDetermine whether a target exists in a matrix where rows are sorted and each row starts after the previous row ends.

# %%
"""0074 — Search a 2D Matrix"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
