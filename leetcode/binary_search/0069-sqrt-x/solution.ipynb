# %% [markdown]
# # 0069 — Sqrt(x)Link: https://leetcode.com/problems/sqrt-x/## SummaryCompute the integer square root of a non-negative integer (the floor of the true square root).

# %%
"""0069 — Sqrt(x)"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0069 — Sqrt(x)"""from __future__ import annotationsclass Solution:    pass```
