# %% [markdown]
# # 0153 — Find Minimum in Rotated Sorted ArrayLink: https://leetcode.com/problems/find-minimum-in-rotated-sorted-array/## SummaryFind the minimum element in a rotated sorted array in logarithmic time.

# %%
"""0153 — Find Minimum in Rotated Sorted Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0153 — Find Minimum in Rotated Sorted Array"""from __future__ import annotationsclass Solution:    pass```
