# %% [markdown]
# # 0033 — Search in Rotated Sorted ArrayLink: https://leetcode.com/problems/search-in-rotated-sorted-array/## SummarySearch for a target value in a rotated sorted array and return its index or -1 in logarithmic time.

# %%
"""0033 — Search in Rotated Sorted Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0033 — Search in Rotated Sorted Array"""from __future__ import annotationsclass Solution:    pass```
