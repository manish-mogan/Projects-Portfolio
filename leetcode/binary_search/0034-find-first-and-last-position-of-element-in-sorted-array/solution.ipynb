# %% [markdown]
# # 0034 — Find First and Last Position of Element in Sorted ArrayLink: https://leetcode.com/problems/find-first-and-last-position-of-element-in-sorted-array/## SummaryIn a sorted array, find the starting and ending indices of a target value, or return [-1, -1] if absent.

# %%
"""0034 — Find First and Last Position of Element in Sorted Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
