# %% [markdown]
# # 0852 — Peak Index in a Mountain ArrayLink: https://leetcode.com/problems/peak-index-in-a-mountain-array/## SummaryGiven an array that increases then decreases, find the index of the peak element using logarithmic time.

# %%
"""0852 — Peak Index in a Mountain Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
