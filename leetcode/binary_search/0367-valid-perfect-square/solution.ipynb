# %% [markdown]
# # 0367 — Valid Perfect SquareLink: https://leetcode.com/problems/valid-perfect-square/## SummaryDetermine whether a positive integer is a perfect square without using built-in square root functions.

# %%
"""0367 — Valid Perfect Square"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0367 — Valid Perfect Square"""from __future__ import annotationsclass Solution:    pass```
