# %% [markdown]
# # 0704 — Binary SearchLink: https://leetcode.com/problems/binary-search/## SummaryPerform binary search on a sorted array to find a target index or -1 if missing.

# %%
"""0704 — Binary Search"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0704 — Binary Search"""from __future__ import annotationsclass Solution:    pass```
