# %% [markdown]
# # 0278 — First Bad VersionLink: https://leetcode.com/problems/first-bad-version/## SummaryUsing an API that tells whether a version is bad, find the first bad version with minimal calls.

# %%
"""0278 — First Bad Version"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0278 — First Bad Version"""from __future__ import annotationsclass Solution:    pass```
