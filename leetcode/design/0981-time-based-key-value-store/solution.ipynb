# %% [markdown]
# # 0981 — Time Based Key-Value StoreLink: https://leetcode.com/problems/time-based-key-value-store/## SummaryDesign a time-based key-value store supporting set(key, value, timestamp) and get(key, timestamp) returning the latest value at or before the timestamp.

# %%
"""0981 — Time Based Key-Value Store"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
