# %% [markdown]
# # 1433 — Check If a String Can Break Another StringLink: https://leetcode.com/problems/check-if-a-string-can-break-another-string/## SummaryDetermine whether one string can 'break' another after rearranging both, meaning it is >= at every position in sorted order (or vice versa).

# %%
"""1433 — Check If a String Can Break Another String"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
