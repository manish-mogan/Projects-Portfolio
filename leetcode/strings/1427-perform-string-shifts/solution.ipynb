# %% [markdown]
# # 1427 — Perform String ShiftsLink: https://leetcode.com/problems/perform-string-shifts/## SummaryApply a sequence of left/right shift operations to a string and return the final string.

# %%
"""1427 — Perform String Shifts"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1427 — Perform String Shifts"""from __future__ import annotationsclass Solution:    pass```
