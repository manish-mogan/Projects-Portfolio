# %% [markdown]
# # 0151 — Reverse Words in a StringLink: https://leetcode.com/problems/reverse-words-in-a-string/## SummaryReverse the order of words in a string, collapsing extra spaces so words are separated by single spaces.

# %%
"""0151 — Reverse Words in a String"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
