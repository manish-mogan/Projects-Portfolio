# %% [markdown]
# # 1160 — Find Words That Can Be Formed by CharactersLink: https://leetcode.com/problems/find-words-that-can-be-formed-by-characters/## SummaryGiven words and available characters, sum lengths of words that can be formed using the characters with limited counts.

# %%
"""1160 — Find Words That Can Be Formed by Characters"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1160 — Find Words That Can Be Formed by Characters"""from __future__ import annotationsclass Solution:    pass```
