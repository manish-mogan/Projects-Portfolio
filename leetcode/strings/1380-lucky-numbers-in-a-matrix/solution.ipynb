# %% [markdown]
# # 1380 — Lucky Numbers in a MatrixLink: https://leetcode.com/problems/lucky-numbers-in-a-matrix/## SummaryFind all matrix entries that are the minimum in their row and simultaneously the maximum in their column.

# %%
"""1380 — Lucky Numbers in a Matrix"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1380 — Lucky Numbers in a Matrix"""from __future__ import annotationsclass Solution:    pass```
