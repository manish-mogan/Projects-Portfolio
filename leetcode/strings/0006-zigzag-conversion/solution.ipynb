# %% [markdown]
# # 0006 — ZigZag ConversionLink: https://leetcode.com/problems/zigzag-conversion/## SummaryWrite the string in a zigzag pattern across a given number of rows and read it row-by-row to form the converted string.

# %%
"""0006 — ZigZag Conversion"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
