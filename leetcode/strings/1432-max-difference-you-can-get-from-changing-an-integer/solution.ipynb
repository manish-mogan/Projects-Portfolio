# %% [markdown]
# # 1432 — Max Difference You Can Get From Changing an IntegerLink: https://leetcode.com/problems/max-difference-you-can-get-from-changing-an-integer/## SummaryMaximize the difference between two numbers formed by replacing digits consistently in the original number (choose replacements for max and min).

# %%
"""1432 — Max Difference You Can Get From Changing an Integer"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1432 — Max Difference You Can Get From Changing an Integer"""from __future__ import annotationsclass Solution:    pass```
