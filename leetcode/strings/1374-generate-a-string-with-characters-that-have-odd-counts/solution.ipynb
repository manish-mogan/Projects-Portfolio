# %% [markdown]
# # 1374 — Generate a String With Characters That Have Odd CountsLink: https://leetcode.com/problems/generate-a-string-with-characters-that-have-odd-counts/## SummaryConstruct a string of length n using lowercase letters such that every character used appears an odd number of times.

# %%
"""1374 — Generate a String With Characters That Have Odd Counts"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
