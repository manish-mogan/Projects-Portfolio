# %% [markdown]
# # 0383 — Ransom NoteLink: https://leetcode.com/problems/ransom-note/## SummaryDetermine if a ransom note string can be constructed from the letters available in a magazine string.

# %%
"""0383 — Ransom Note"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
