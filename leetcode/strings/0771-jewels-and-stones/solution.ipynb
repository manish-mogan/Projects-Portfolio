# %% [markdown]
# # 0771 — Jewels and StonesLink: https://leetcode.com/problems/jewels-and-stones/## SummaryCount how many stones are jewels given strings describing jewel types and stones you have.

# %%
"""0771 — Jewels and Stones"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
