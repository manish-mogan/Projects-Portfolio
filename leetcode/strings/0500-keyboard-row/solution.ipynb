# %% [markdown]
# # 0500 — Keyboard RowLink: https://leetcode.com/problems/keyboard-row/## SummaryReturn the words that can be typed using letters from only one row of a standard keyboard layout.

# %%
"""0500 — Keyboard Row"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
