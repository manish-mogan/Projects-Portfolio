# %% [markdown]
# # 1370 — Increasing Decreasing StringLink: https://leetcode.com/problems/increasing-decreasing-string/## SummaryReorder characters by repeatedly taking the smallest available increasing run, then the largest available decreasing run, until exhausted.

# %%
"""1370 — Increasing Decreasing String"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
