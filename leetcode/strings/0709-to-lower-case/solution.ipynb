# %% [markdown]
# # 0709 — To Lower CaseLink: https://leetcode.com/problems/to-lower-case/## SummaryConvert all uppercase letters in a string to lowercase.

# %%
"""0709 — To Lower Case"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0709 — To Lower Case"""from __future__ import annotationsclass Solution:    pass```
