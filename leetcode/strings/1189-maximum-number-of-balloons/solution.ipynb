# %% [markdown]
# # 1189 — Maximum Number of BalloonsLink: https://leetcode.com/problems/maximum-number-of-balloons/## SummaryGiven letters in a string, compute how many times the word 'balloon' can be formed.

# %%
"""1189 — Maximum Number of Balloons"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
