# %% [markdown]
# # 0005 — Longest Palindromic SubstringLink: https://leetcode.com/problems/longest-palindromic-substring/## SummaryFind the longest contiguous substring of a string that reads the same forward and backward.

# %%
"""0005 — Longest Palindromic Substring"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
