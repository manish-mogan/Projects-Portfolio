# %% [markdown]
# # 1400 — Construct K Palindrome StringsLink: https://leetcode.com/problems/construct-k-palindrome-strings/## SummaryDetermine whether a string’s characters can be rearranged into exactly k non-empty palindrome strings.

# %%
"""1400 — Construct K Palindrome Strings"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1400 — Construct K Palindrome Strings"""from __future__ import annotationsclass Solution:    pass```
