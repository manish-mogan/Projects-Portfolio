# %% [markdown]
# # 0056 — Merge IntervalsLink: https://leetcode.com/problems/merge-intervals/## SummaryGiven intervals, merge all that overlap and return the resulting set of disjoint intervals.

# %%
"""0056 — Merge Intervals"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
