# %% [markdown]
# # 0605 — Can Place FlowersLink: https://leetcode.com/problems/can-place-flowers/## SummaryGiven a flowerbed array and n new flowers, determine if n flowers can be planted without adjacent flowers.

# %%
"""0605 — Can Place Flowers"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
