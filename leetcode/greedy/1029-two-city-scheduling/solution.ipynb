# %% [markdown]
# # 1029 — Two City SchedulingLink: https://leetcode.com/problems/two-city-scheduling/## SummarySend exactly N people to each of two cities with minimum total cost given per-person costs for each city.

# %%
"""1029 — Two City Scheduling"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
