# %% [markdown]
# # 0122 — Best Time to Buy and Sell Stock IILink: https://leetcode.com/problems/best-time-to-buy-and-sell-stock-ii/## SummaryCompute the maximum profit from as many stock trades as you like, but you must sell before buying again.

# %%
"""0122 — Best Time to Buy and Sell Stock II"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0122 — Best Time to Buy and Sell Stock II"""from __future__ import annotationsclass Solution:    pass```
