# %% [markdown]
# # 0024 — Swap Nodes in PairsLink: https://leetcode.com/problems/swap-nodes-in-pairs/## SummarySwap every two adjacent nodes in a linked list and return the new head without changing node values.

# %%
"""0024 — Swap Nodes in Pairs"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0024 — Swap Nodes in Pairs"""from __future__ import annotationsclass Solution:    pass```
