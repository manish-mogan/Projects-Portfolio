# %% [markdown]
# # 0206 — Reverse Linked ListLink: https://leetcode.com/problems/reverse-linked-list/## SummaryReverse a singly linked list and return the new head.

# %%
"""0206 — Reverse Linked List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
