# %% [markdown]
# # 0876 — Middle of the Linked ListLink: https://leetcode.com/problems/middle-of-the-linked-list/## SummaryReturn the middle node of a linked list (if even length, return the second middle).

# %%
"""0876 — Middle of the Linked List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0876 — Middle of the Linked List"""from __future__ import annotationsclass Solution:    pass```
