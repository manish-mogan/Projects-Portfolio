# %% [markdown]
# # 0707 — Design Linked ListLink: https://leetcode.com/problems/design-linked-list/## SummaryDesign a linked list with operations like get, add at head/tail/index, and delete at index.

# %%
"""0707 — Design Linked List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
