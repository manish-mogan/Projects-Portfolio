# %% [markdown]
# # 0237 — Delete Node in a Linked ListLink: https://leetcode.com/problems/delete-node-in-a-linked-list/## SummaryDelete a node from a singly linked list when only that node is given (not the head).

# %%
"""0237 — Delete Node in a Linked List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
