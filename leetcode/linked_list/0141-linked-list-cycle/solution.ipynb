# %% [markdown]
# # 0141 — Linked List CycleLink: https://leetcode.com/problems/linked-list-cycle/## SummaryDetect whether a linked list contains a cycle.

# %%
"""0141 — Linked List Cycle"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0141 — Linked List Cycle"""from __future__ import annotationsclass Solution:    pass```
