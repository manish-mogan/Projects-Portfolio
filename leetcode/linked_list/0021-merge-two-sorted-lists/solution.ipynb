# %% [markdown]
# # 0021 — Merge Two Sorted ListsLink: https://leetcode.com/problems/merge-two-sorted-lists/## SummaryMerge two sorted linked lists into a single sorted linked list.

# %%
"""0021 — Merge Two Sorted Lists"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
