# %% [markdown]
# # 0019 — Remove Nth Node From End of ListLink: https://leetcode.com/problems/remove-nth-node-from-end-of-list/## SummaryRemove the n-th node from the end of a singly linked list and return the head of the modified list.

# %%
"""0019 — Remove Nth Node From End of List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
