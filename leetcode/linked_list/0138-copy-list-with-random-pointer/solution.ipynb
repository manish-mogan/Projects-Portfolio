# %% [markdown]
# # 0138 — Copy List with Random PointerLink: https://leetcode.com/problems/copy-list-with-random-pointer/## SummaryCreate a deep copy of a linked list where each node has both next and random pointers.

# %%
"""0138 — Copy List with Random Pointer"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0138 — Copy List with Random Pointer"""from __future__ import annotationsclass Solution:    pass```
