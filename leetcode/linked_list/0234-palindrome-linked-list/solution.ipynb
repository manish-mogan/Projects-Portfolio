# %% [markdown]
# # 0234 — Palindrome Linked ListLink: https://leetcode.com/problems/palindrome-linked-list/## SummaryDetermine whether a linked list’s values form a palindrome sequence.

# %%
"""0234 — Palindrome Linked List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0234 — Palindrome Linked List"""from __future__ import annotationsclass Solution:    pass```
