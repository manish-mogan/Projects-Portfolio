# %% [markdown]
# # 0203 — Remove Linked List ElementsLink: https://leetcode.com/problems/remove-linked-list-elements/## SummaryRemove all nodes with a given value from a linked list and return the new head.

# %%
"""0203 — Remove Linked List Elements"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0203 — Remove Linked List Elements"""from __future__ import annotationsclass Solution:    pass```
