# %% [markdown]
# # 0160 — Intersection of Two Linked ListsLink: https://leetcode.com/problems/intersection-of-two-linked-lists/## SummaryGiven two singly linked lists, find the node where they intersect (by reference), or return None if they do not.

# %%
"""0160 — Intersection of Two Linked Lists"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0160 — Intersection of Two Linked Lists"""from __future__ import annotationsclass Solution:    pass```
