# %% [markdown]
# # 0143 — Reorder ListLink: https://leetcode.com/problems/reorder-list/## SummaryReorder a linked list to interleave from the ends inward: first, last, second, second-last, and so on.

# %%
"""0143 — Reorder List"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
