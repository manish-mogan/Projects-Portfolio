# %% [markdown]
# # 0392 — Is SubsequenceLink: https://leetcode.com/problems/is-subsequence/## SummaryDetermine whether one string is a subsequence of another (characters in order, not necessarily contiguous).

# %%
"""0392 — Is Subsequence"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0392 — Is Subsequence"""from __future__ import annotationsclass Solution:    pass```
