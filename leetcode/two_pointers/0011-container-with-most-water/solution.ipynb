# %% [markdown]
# # 0011 — Container With Most WaterLink: https://leetcode.com/problems/container-with-most-water/## SummaryGiven heights of vertical lines, choose two lines to maximize the area of water they can contain.

# %%
"""0011 — Container With Most Water"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0011 — Container With Most Water"""from __future__ import annotationsclass Solution:    pass```
