# %% [markdown]
# # 0026 — Remove Duplicates from Sorted ArrayLink: https://leetcode.com/problems/remove-duplicates-from-sorted-array/## SummaryRemove duplicates in-place from a sorted array so each element appears once, returning the new length.

# %%
"""0026 — Remove Duplicates from Sorted Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0026 — Remove Duplicates from Sorted Array"""from __future__ import annotationsclass Solution:    pass```
