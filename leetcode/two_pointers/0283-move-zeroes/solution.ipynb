# %% [markdown]
# # 0283 — Move ZeroesLink: https://leetcode.com/problems/move-zeroes/## SummaryMove all zeros in an array to the end while maintaining the relative order of non-zero elements.

# %%
"""0283 — Move Zeroes"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
