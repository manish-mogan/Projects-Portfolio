# %% [markdown]
# # 0844 — Backspace String CompareLink: https://leetcode.com/problems/backspace-string-compare/## SummaryCompare two strings after applying backspace operations where '#' deletes the previous character.

# %%
"""0844 — Backspace String Compare"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
