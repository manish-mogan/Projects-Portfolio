# %% [markdown]
# # 0125 — Valid PalindromeLink: https://leetcode.com/problems/valid-palindrome/## SummaryCheck if a string is a palindrome when considering only letters/digits and ignoring case.

# %%
"""0125 — Valid Palindrome"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
