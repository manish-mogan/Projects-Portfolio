# %% [markdown]
# # 0881 — Boats to Save PeopleLink: https://leetcode.com/problems/boats-to-save-people/## SummaryGiven people’s weights and a boat limit, find the minimum number of boats needed if each boat carries at most two people.

# %%
"""0881 — Boats to Save People"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
