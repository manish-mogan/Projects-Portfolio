# %% [markdown]
# # 0027 — Remove ElementLink: https://leetcode.com/problems/remove-element/## SummaryRemove all instances of a given value from an array in-place and return the length of the remaining prefix.

# %%
"""0027 — Remove Element"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
