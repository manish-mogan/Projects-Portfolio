# %% [markdown]
# # 0014 — Longest Common PrefixLink: https://leetcode.com/problems/longest-common-prefix/## SummaryGiven a list of strings, return the longest prefix shared by all of them (or empty if none).

# %%
"""0014 — Longest Common Prefix"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0014 — Longest Common Prefix"""from __future__ import annotationsclass Solution:    pass```
