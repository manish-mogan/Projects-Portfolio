# %% [markdown]
# # 0345 — Reverse Vowels of a StringLink: https://leetcode.com/problems/reverse-vowels-of-a-string/## SummaryReverse only the vowels in a string while keeping other characters in their original positions.

# %%
"""0345 — Reverse Vowels of a String"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0345 — Reverse Vowels of a String"""from __future__ import annotationsclass Solution:    pass```
