# %% [markdown]
# # 0145 — Binary Tree Postorder Traverlsal
#
# Link: https://leetcode.com/problems/binary-tree-postorder-traverlsal/
#
# ## Summary
# Return the postorder traversal of a binary tree's node values.

# %%
"""0145 — Binary Tree Postorder Traverlsal"""

from __future__ import annotations


class Solution:
    pass
