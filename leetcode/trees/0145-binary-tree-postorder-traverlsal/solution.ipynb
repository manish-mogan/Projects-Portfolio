# %% [markdown]
# # 0145 — Binary Tree Postorder TraverlsalLink: https://leetcode.com/problems/binary-tree-postorder-traverlsal/## SummaryReturn the postorder traversal of a binary tree's node values.

# %%
"""0145 — Binary Tree Postorder Traverlsal"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0145 — Binary Tree Postorder Traverlsal"""from __future__ import annotationsclass Solution:    pass```
