# %% [markdown]
# # 0872 — Leaf-Similar TreesLink: https://leetcode.com/problems/leaf-similar-trees/## SummaryDetermine whether two binary trees have identical sequences of leaf values from left to right.

# %%
"""0872 — Leaf-Similar Trees"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0872 — Leaf-Similar Trees"""from __future__ import annotationsclass Solution:    pass```
