# %% [markdown]
# # 0543 — Diameter of Binary TreeLink: https://leetcode.com/problems/diameter-of-binary-tree/## SummaryCompute the diameter of a binary tree (the maximum number of edges on any path between two nodes).

# %%
"""0543 — Diameter of Binary Tree"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
