# %% [markdown]
# # 0700 — Search in a Binary Search TreeLink: https://leetcode.com/problems/search-in-a-binary-search-tree/## SummarySearch for a given value in a binary search tree and return the subtree rooted at that node (or None).

# %%
"""0700 — Search in a Binary Search Tree"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0700 — Search in a Binary Search Tree"""from __future__ import annotationsclass Solution:    pass```
