# %% [markdown]
# # 0993 — Cousins in Binary TreeLink: https://leetcode.com/problems/cousins-in-binary-tree/## SummaryDetermine whether two nodes in a binary tree are cousins (same depth but different parents).

# %%
"""0993 — Cousins in Binary Tree"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
