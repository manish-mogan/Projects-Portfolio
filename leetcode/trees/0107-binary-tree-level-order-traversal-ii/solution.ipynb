# %% [markdown]
# # 0107 — Binary Tree Level Order Traversal IILink: https://leetcode.com/problems/binary-tree-level-order-traversal-ii/## SummaryReturn the level-order traversal of a binary tree from bottom level up to the root level.

# %%
"""0107 — Binary Tree Level Order Traversal II"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0107 — Binary Tree Level Order Traversal II"""from __future__ import annotationsclass Solution:    pass```
