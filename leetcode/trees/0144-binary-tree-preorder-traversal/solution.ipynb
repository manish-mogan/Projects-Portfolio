# %% [markdown]
# # 0144 — Binary Tree Preorder TraversalLink: https://leetcode.com/problems/binary-tree-preorder-traversal/## SummaryReturn the preorder traversal of a binary tree's node values.

# %%
"""0144 — Binary Tree Preorder Traversal"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
