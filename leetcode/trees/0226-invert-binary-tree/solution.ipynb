# %% [markdown]
# # 0226 — Invert Binary TreeLink: https://leetcode.com/problems/invert-binary-tree/## SummaryInvert a binary tree by swapping left and right children for every node.

# %%
"""0226 — Invert Binary Tree"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
