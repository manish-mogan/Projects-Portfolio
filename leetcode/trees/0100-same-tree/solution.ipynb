# %% [markdown]
# # 0100 — Same TreeLink: https://leetcode.com/problems/same-tree/## SummaryDetermine whether two binary trees are structurally identical and have equal values at all corresponding nodes.

# %%
"""0100 — Same Tree"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
