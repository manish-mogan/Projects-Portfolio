# %% [markdown]
# # 0617 — Merge Two Binary TreesLink: https://leetcode.com/problems/merge-two-binary-trees/## SummaryMerge two binary trees by summing overlapping node values and keeping non-null branches where only one tree has nodes.

# %%
"""0617 — Merge Two Binary Trees"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
