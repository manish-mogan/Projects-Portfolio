# %% [markdown]
# # 0102 — Binary Tree Level Order TraversalLink: https://leetcode.com/problems/binary-tree-level-order-traversal/## SummaryReturn the level-order (breadth-first) traversal of a binary tree as a list of levels.

# %%
"""0102 — Binary Tree Level Order Traversal"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
