# %% [markdown]
# # 1431 — Kids With the Greatest Number of CandiesLink: https://leetcode.com/problems/kids-with-the-greatest-number-of-candies/## SummaryFor each child’s candies, determine if they could have the greatest count after receiving some extra candies.

# %%
"""1431 — Kids With the Greatest Number of Candies"""from __future__ import annotationsfrom typing import Listclass Solution:    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:        pass

# %% [markdown]
# ## Solution"""Approach: compare each candies[i] + extraCandies to max(candies).Time: O(n)Space: O(1) extra (output excluded)"""from __future__ import annotationsfrom typing import Listclass Solution:    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:        m = max(candies)        return [c + extraCandies >= m for c in candies]
