# %% [markdown]
# # 1480 — Running Sum of 1d ArrayLink: https://leetcode.com/problems/running-sum-of-1d-array/## SummaryCompute the running prefix sum array where each element is the sum of all elements up to that index.

# %%
"""1480 — Running Sum of 1d Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1480 — Running Sum of 1d Array"""from __future__ import annotationsclass Solution:    pass```
