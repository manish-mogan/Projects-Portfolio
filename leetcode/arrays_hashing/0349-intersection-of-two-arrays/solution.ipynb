# %% [markdown]
# # 0349 — Intersection of Two ArraysLink: https://leetcode.com/problems/intersection-of-two-arrays/## SummaryCompute the set intersection of two arrays, returning unique common elements.

# %%
"""0349 — Intersection of Two Arrays"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0349 — Intersection of Two Arrays"""from __future__ import annotationsclass Solution:    pass```
