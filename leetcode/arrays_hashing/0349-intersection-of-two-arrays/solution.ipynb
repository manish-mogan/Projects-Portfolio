# %% [markdown]
# # 0349 — Intersection of Two ArraysLink: https://leetcode.com/problems/intersection-of-two-arrays/## SummaryCompute the set intersection of two arrays, returning unique common elements.

# %%
"""0349 — Intersection of Two Arrays"""from __future__ import annotationsfrom typing import Listclass Solution:    def intersection(self, nums1: List[int], nums2: List[int]) -> List[int]:        pass

# %% [markdown]
# ## Solution**Approach:** set intersection.**Complexity:**- Time: O(n+m)- Space: O(n+m) worst-case(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsfrom typing import Listclass Solution:    def intersection(self, nums1: List[int], nums2: List[int]) -> List[int]:        return list(set(nums1) & set(nums2))
