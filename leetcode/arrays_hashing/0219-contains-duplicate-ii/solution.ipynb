# %% [markdown]
# # 0219 — Contains Duplicate IILink: https://leetcode.com/problems/contains-duplicate-ii/## SummaryCheck whether the same value appears at two indices whose difference is at most k.

# %%
"""0219 — Contains Duplicate II"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0219 — Contains Duplicate II"""from __future__ import annotationsclass Solution:    pass```
