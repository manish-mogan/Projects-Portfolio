# %% [markdown]
# # 0890 — Find and Replace PatternLink: https://leetcode.com/problems/find-and-replace-pattern/## SummaryFind which words match a pattern by a consistent one-to-one letter mapping.

# %%
"""0890 — Find and Replace Pattern"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0890 — Find and Replace Pattern"""from __future__ import annotationsclass Solution:    pass```
