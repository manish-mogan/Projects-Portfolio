# %% [markdown]
# # 0242 — Valid AnagramLink: https://leetcode.com/problems/valid-anagram/## SummaryDetermine whether two strings contain the same character counts (i.e., are anagrams).

# %%
"""0242 — Valid Anagram"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0242 — Valid Anagram"""from __future__ import annotationsclass Solution:    pass```
