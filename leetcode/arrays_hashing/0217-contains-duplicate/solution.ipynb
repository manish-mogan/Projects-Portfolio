# %% [markdown]
# # 0217 — Contains DuplicateLink: https://leetcode.com/problems/contains-duplicate/## SummaryDetermine whether an array contains any duplicate value.

# %%
"""0217 — Contains Duplicate"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0217 — Contains Duplicate"""from __future__ import annotationsclass Solution:    pass```
