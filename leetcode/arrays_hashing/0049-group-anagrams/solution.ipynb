# %% [markdown]
# # 0049 — Group Anagrams
#
# Link: https://leetcode.com/problems/group-anagrams/
#
# ## Summary
# Group strings into sets where each set contains words that are anagrams of each other.

# %%
"""0049 — Group Anagrams"""

from __future__ import annotations

from typing import List


class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        pass

# %% [markdown]
# ## Solution**Approach:** group by 26-letter frequency signature.**Complexity:**- Time: O(n*k)- Space: O(n*k) (output) + O(n) keys(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotations

from collections import defaultdict
from typing import List


class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:
        groups: dict[tuple[int, ...], list[str]] = defaultdict(list)
        for s in strs:
            counts = [0] * 26
            for ch in s:
                counts[ord(ch) - ord("a")] += 1
            groups[tuple(counts)].append(s)
        return list(groups.values())
