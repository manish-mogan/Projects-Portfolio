# %% [markdown]
# # 0049 — Group Anagrams
#
# Link: https://leetcode.com/problems/group-anagrams/
#
# ## Summary
# Group strings into sets where each set contains words that are anagrams of each other.

# %%
## Solution

Group words by a signature that’s identical for anagrams. A common signature is a 26-length character frequency vector (for lowercase English letters). Convert it to a tuple so it can be used as a dictionary key.

- Time: $O(n \cdot k)$ where $n$ is number of strings and $k$ is max string length
- Space: $O(n \cdot k)$ for storing grouped strings (plus keys)

# %% [markdown]
# ## Solution
#
# ```python
# """0049 — Group Anagrams"""
#
# from __future__ import annotations
#
#
# class Solution:
#     pass
# ```
