# %% [markdown]
# # 0724 — Find Pivot IndexLink: https://leetcode.com/problems/find-pivot-index/## SummaryFind an index where the sum of elements to the left equals the sum of elements to the right (pivot index).

# %%
"""0724 — Find Pivot Index"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0724 — Find Pivot Index"""from __future__ import annotationsclass Solution:    pass```
