# %% [markdown]
# # 1426 — Counting ElementsLink: https://leetcode.com/problems/counting-elements/## SummaryCount elements x in an array such that x+1 is also present in the array (counting each occurrence of x).

# %%
"""1426 — Counting Elements"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1426 — Counting Elements"""from __future__ import annotationsclass Solution:    pass```
