# %% [markdown]
# # 0347 — Top K Frequent ElementsLink: https://leetcode.com/problems/top-k-frequent-elements/## SummaryReturn the k most frequent elements in an array.

# %%
"""0347 — Top K Frequent Elements"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0347 — Top K Frequent Elements"""from __future__ import annotationsclass Solution:    pass```
