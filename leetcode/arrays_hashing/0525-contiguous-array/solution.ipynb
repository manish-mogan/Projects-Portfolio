# %% [markdown]
# # 0525 — Contiguous ArrayLink: https://leetcode.com/problems/contiguous-array/## SummaryFind the maximum length of a contiguous subarray with equal numbers of 0s and 1s.

# %%
"""0525 — Contiguous Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0525 — Contiguous Array"""from __future__ import annotationsclass Solution:    pass```
