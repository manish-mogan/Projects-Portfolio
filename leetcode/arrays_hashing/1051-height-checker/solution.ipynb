# %% [markdown]
# # 1051 — Height CheckerLink: https://leetcode.com/problems/height-checker/## SummaryCount how many indices differ between the original heights array and its sorted version.

# %%
"""1051 — Height Checker"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1051 — Height Checker"""from __future__ import annotationsclass Solution:    pass```
