# %% [markdown]
# # 1207 — Unique Number of OccurrencesLink: https://leetcode.com/problems/unique-number-of-occurrences/## SummaryDetermine whether the frequencies of values in an array are all distinct.

# %%
"""1207 — Unique Number of Occurrences"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1207 — Unique Number of Occurrences"""from __future__ import annotationsclass Solution:    pass```
