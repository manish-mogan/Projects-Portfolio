# %% [markdown]
# # 0152 — Maximum Product SubarrayLink: https://leetcode.com/problems/maximum-product-subarray/## SummaryFind the maximum product of a non-empty contiguous subarray.

# %%
"""0152 — Maximum Product Subarray"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
