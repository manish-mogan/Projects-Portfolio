# %% [markdown]
# # 0941 — Valid Mountain ArrayLink: https://leetcode.com/problems/valid-mountain-array/## SummaryDetermine whether an array forms a valid mountain: strictly increasing to one peak then strictly decreasing.

# %%
"""0941 — Valid Mountain Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0941 — Valid Mountain Array"""from __future__ import annotationsclass Solution:    pass```
