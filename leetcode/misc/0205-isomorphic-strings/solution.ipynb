# %% [markdown]
# # 0205 — Isomorphic StringsLink: https://leetcode.com/problems/isomorphic-strings/## SummaryDetermine if two strings are isomorphic by checking whether characters map consistently in both directions.

# %%
"""0205 — Isomorphic Strings"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0205 — Isomorphic Strings"""from __future__ import annotationsclass Solution:    pass```
