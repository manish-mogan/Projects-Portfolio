# %% [markdown]
# # 0189 — Rotate ArrayLink: https://leetcode.com/problems/rotate-array/## SummaryRotate an array to the right by k steps in-place (or with minimal extra space).

# %%
"""0189 — Rotate Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
