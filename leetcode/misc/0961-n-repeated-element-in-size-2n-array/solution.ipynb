# %% [markdown]
# # 0961 — N-Repeated Element in Size 2N ArrayLink: https://leetcode.com/problems/n-repeated-element-in-size-2n-array/## SummaryIn an array of size 2N where exactly one value repeats N times, find that repeated value.

# %%
"""0961 — N-Repeated Element in Size 2N Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0961 — N-Repeated Element in Size 2N Array"""from __future__ import annotationsclass Solution:    pass```
