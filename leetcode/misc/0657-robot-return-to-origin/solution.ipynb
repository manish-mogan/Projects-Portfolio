# %% [markdown]
# # 0657 — Robot Return to OriginLink: https://leetcode.com/problems/robot-return-to-origin/## SummaryGiven moves on a 2D grid, determine if the robot returns to the origin.

# %%
"""0657 — Robot Return to Origin"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
