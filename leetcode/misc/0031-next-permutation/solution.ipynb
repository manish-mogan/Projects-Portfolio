# %% [markdown]
# # 0031 — Next PermutationLink: https://leetcode.com/problems/next-permutation/## SummaryRearrange numbers into the next lexicographically greater permutation; if none exists, transform into the smallest permutation.

# %%
"""0031 — Next Permutation"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
