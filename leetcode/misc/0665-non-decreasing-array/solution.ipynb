# %% [markdown]
# # 0665 — Non Decreasing ArrayLink: https://leetcode.com/problems/non-decreasing-array/## SummaryDetermine whether an array can become non-decreasing by modifying at most one element.

# %%
"""0665 — Non Decreasing Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
