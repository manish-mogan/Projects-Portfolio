# %% [markdown]
# # 0004 — Median of Two Sorted ArraysLink: https://leetcode.com/problems/median-of-two-sorted-arrays/## SummaryGiven two sorted arrays, compute the median of the combined multiset in better than linear time.

# %%
"""0004 — Median of Two Sorted Arrays"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0004 — Median of Two Sorted Arrays"""from __future__ import annotationsclass Solution:    pass```
