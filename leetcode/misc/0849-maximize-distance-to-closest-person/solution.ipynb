# %% [markdown]
# # 0849 — Maximize Distance to Closest PersonLink: https://leetcode.com/problems/maximize-distance-to-closest-person/## SummaryGiven seats as 0/1, choose an empty seat to maximize distance to the closest occupied seat.

# %%
"""0849 — Maximize Distance to Closest Person"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
