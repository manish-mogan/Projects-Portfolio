# %% [markdown]
# # 0023 — Merge k Sorted ListsLink: https://leetcode.com/problems/merge-k-sorted-lists/## SummaryMerge k sorted linked lists into one sorted list.

# %%
"""0023 — Merge k Sorted Lists"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0023 — Merge k Sorted Lists"""from __future__ import annotationsclass Solution:    pass```
