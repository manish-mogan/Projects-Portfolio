# %% [markdown]
# # 0238 — Product of Array Except SelfLink: https://leetcode.com/problems/product-of-array-except-self/## SummaryFor each index, return the product of all numbers in the array except the one at that index, without using division.

# %%
"""0238 — Product of Array Except Self"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
