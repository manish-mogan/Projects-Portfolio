# %% [markdown]
# # 0118 — Pascal's TriangleLink: https://leetcode.com/problems/pascal-s-triangle/## SummaryGenerate the first n rows of Pascal’s triangle.

# %%
"""0118 — Pascal's Triangle"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
