# %% [markdown]
# # 0131 — Palindrome PositioningLink: https://leetcode.com/problems/palindrome-positioning/## SummaryPartition a string into all possible lists of substrings such that every substring in the partition is a palindrome.

# %%
"""0131 — Palindrome Positioning"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
