# %% [markdown]
# # 0088 — Merge Sorted ArrayLink: https://leetcode.com/problems/merge-sorted-array/## SummaryMerge two sorted arrays into the first one in-place, given that it has enough trailing space.

# %%
"""0088 — Merge Sorted Array"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
