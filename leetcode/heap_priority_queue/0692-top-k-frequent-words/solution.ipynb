# %% [markdown]
# # 0692 — Top K Frequent WordsLink: https://leetcode.com/problems/top-k-frequent-words/## SummaryReturn the k most frequent words, breaking ties by lexicographic order.

# %%
"""0692 — Top K Frequent Words"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
