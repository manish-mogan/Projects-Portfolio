# %% [markdown]
# # 1046 — Last Stone WeightLink: https://leetcode.com/problems/last-stone-weight/## SummaryRepeatedly smash the two heaviest stones; if unequal, the remainder is put back—return the final remaining weight (or 0).

# %%
"""1046 — Last Stone Weight"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
