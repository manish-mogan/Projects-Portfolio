# %% [markdown]
# # 0373 — Find K Pairs with Smallers SumsLink: https://leetcode.com/problems/find-k-pairs-with-smallers-sums/## SummaryGiven two sorted arrays, find the k pairs (one from each array) with the smallest sums.

# %%
"""0373 — Find K Pairs with Smallers Sums"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
