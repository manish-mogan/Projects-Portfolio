# %% [markdown]
# # 0075 — Sort ColorsLink: https://leetcode.com/problems/sort-colors/## SummarySort an array containing only 0s, 1s, and 2s in-place (three-way partition).

# %%
"""0075 — Sort Colors"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0075 — Sort Colors"""from __future__ import annotationsclass Solution:    pass```
