# %% [markdown]
# # 0463 — Island PerimeterLink: https://leetcode.com/problems/island-perimeter/## SummaryGiven a 0/1 grid representing land and water, compute the perimeter of the island cells.

# %%
"""0463 — Island Perimeter"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
