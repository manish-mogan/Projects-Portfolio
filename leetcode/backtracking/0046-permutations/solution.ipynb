# %% [markdown]
# # 0046 — PermutationsLink: https://leetcode.com/problems/permutations/## SummaryReturn all possible permutations of a list of distinct integers.

# %%
"""0046 — Permutations"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0046 — Permutations"""from __future__ import annotationsclass Solution:    pass```
