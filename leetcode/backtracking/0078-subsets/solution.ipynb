# %% [markdown]
# # 0078 — SubsetsLink: https://leetcode.com/problems/subsets/## SummaryReturn all subsets (the power set) of a list of distinct integers.

# %%
"""0078 — Subsets"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
