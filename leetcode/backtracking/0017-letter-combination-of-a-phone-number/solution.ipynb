# %% [markdown]
# # 0017 — Letter Combination of a Phone NumberLink: https://leetcode.com/problems/letter-combination-of-a-phone-number/## SummaryGiven digits from 2–9, generate all possible letter strings based on the classic phone keypad mapping.

# %%
"""0017 — Letter Combination of a Phone Number"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0017 — Letter Combination of a Phone Number"""from __future__ import annotationsclass Solution:    pass```
