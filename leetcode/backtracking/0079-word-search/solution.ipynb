# %% [markdown]
# # 0079 — Word SearchLink: https://leetcode.com/problems/word-search/## SummaryCheck if a given word can be formed in a grid by moving horizontally/vertically without reusing a cell.

# %%
"""0079 — Word Search"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
