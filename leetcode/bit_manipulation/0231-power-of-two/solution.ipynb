# %% [markdown]
# # 0231 — Power of TwoLink: https://leetcode.com/problems/power-of-two/## SummaryDetermine whether an integer is a power of two.

# %%
"""0231 — Power of Two"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
