# %% [markdown]
# # 0268 — Missing NumberLink: https://leetcode.com/problems/missing-number/## SummaryGiven numbers from 0..n with one missing, find the missing value.

# %%
"""0268 — Missing Number"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0268 — Missing Number"""from __future__ import annotationsclass Solution:    pass```
