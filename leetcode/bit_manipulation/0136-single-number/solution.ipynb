# %% [markdown]
# # 0136 — Single NumberLink: https://leetcode.com/problems/single-number/## SummaryIn an array where every element appears twice except one, find the unique element using bitwise reasoning.

# %%
"""0136 — Single Number"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
