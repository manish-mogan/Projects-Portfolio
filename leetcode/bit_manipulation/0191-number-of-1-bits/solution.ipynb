# %% [markdown]
# # 0191 — Number of 1 BitsLink: https://leetcode.com/problems/number-of-1-bits/## SummaryCount the number of set bits (1s) in the binary representation of an unsigned integer.

# %%
"""0191 — Number of 1 Bits"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
