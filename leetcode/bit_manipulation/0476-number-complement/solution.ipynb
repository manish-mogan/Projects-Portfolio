# %% [markdown]
# # 0476 — Number ComplementLink: https://leetcode.com/problems/number-complement/## SummaryCompute the bitwise complement of a positive integer over its significant bits.

# %%
"""0476 — Number Complement"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0476 — Number Complement"""from __future__ import annotationsclass Solution:    pass```
