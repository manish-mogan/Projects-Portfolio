# %% [markdown]
# # 0856 — Score of ParenthesesLink: https://leetcode.com/problems/score-of-parentheses/## SummaryCompute the score of a balanced parentheses string using the specified scoring rules based on nesting and concatenation.

# %%
"""0856 — Score of Parentheses"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
