# %% [markdown]
# # 0678 — Valid Parenthesis StringLink: https://leetcode.com/problems/valid-parenthesis-string/## SummaryGiven a string with '(', ')', and '*', determine if it can be a valid parenthesis string where '*' can act as '(', ')', or empty.

# %%
"""0678 — Valid Parenthesis String"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0678 — Valid Parenthesis String"""from __future__ import annotationsclass Solution:    pass```
