# %% [markdown]
# # 1047 — Remove All Adjacent Duplicates In StringLink: https://leetcode.com/problems/remove-all-adjacent-duplicates-in-string/## SummaryRepeatedly remove adjacent equal characters from a string until no more removals are possible.

# %%
"""1047 — Remove All Adjacent Duplicates In String"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1047 — Remove All Adjacent Duplicates In String"""from __future__ import annotationsclass Solution:    pass```
