# %% [markdown]
# # 0739 — Daily TemperaturesLink: https://leetcode.com/problems/daily-temperatures/## SummaryFor each day’s temperature, compute how many days you must wait to see a warmer temperature (or 0 if none).

# %%
"""0739 — Daily Temperatures"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
