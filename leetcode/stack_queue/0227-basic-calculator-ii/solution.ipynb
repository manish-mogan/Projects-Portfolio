# %% [markdown]
# # 0227 — Basic Calculator IILink: https://leetcode.com/problems/basic-calculator-ii/## SummaryEvaluate a basic arithmetic expression with non-negative integers and +, -, *, / respecting operator precedence.

# %%
"""0227 — Basic Calculator II"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
