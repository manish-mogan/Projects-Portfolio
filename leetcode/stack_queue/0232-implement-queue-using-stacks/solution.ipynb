# %% [markdown]
# # 0232 — Implement Queue using StacksLink: https://leetcode.com/problems/implement-queue-using-stacks/## SummaryImplement a FIFO queue using only stack operations.

# %%
"""0232 — Implement Queue using Stacks"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0232 — Implement Queue using Stacks"""from __future__ import annotationsclass Solution:    pass```
