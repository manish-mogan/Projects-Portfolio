# %% [markdown]
# # 0402 — Remove K DigitsLink: https://leetcode.com/problems/remove-k-digits/## SummaryRemove exactly k digits from a non-negative integer string to produce the smallest possible resulting number string.

# %%
"""0402 — Remove K Digits"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
