# %% [markdown]
# # 0155 — Min StackLink: https://leetcode.com/problems/min-stack/## SummaryDesign a stack supporting push, pop, top, and retrieving the current minimum in constant time.

# %%
"""0155 — Min Stack"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0155 — Min Stack"""from __future__ import annotationsclass Solution:    pass```
