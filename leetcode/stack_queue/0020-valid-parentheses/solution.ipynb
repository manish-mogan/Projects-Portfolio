# %% [markdown]
# # 0020 — Valid ParenthesesLink: https://leetcode.com/problems/valid-parentheses/## SummaryCheck whether a string of brackets is properly balanced and correctly nested.

# %%
"""0020 — Valid Parentheses"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0020 — Valid Parentheses"""from __future__ import annotationsclass Solution:    pass```
