# %% [markdown]
# # 0443 — String CompressionLink: https://leetcode.com/problems/string-compression/## SummaryCompress a character array in-place using run-length encoding and return the new length.

# %%
"""0443 — String Compression"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0443 — String Compression"""from __future__ import annotationsclass Solution:    pass```
