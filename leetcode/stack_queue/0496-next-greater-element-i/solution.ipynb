# %% [markdown]
# # 0496 — Next Greater Element ILink: https://leetcode.com/problems/next-greater-element-i/## SummaryFor each element in nums1, find its next greater element to the right in nums2 (or -1 if none).

# %%
"""0496 — Next Greater Element I"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
