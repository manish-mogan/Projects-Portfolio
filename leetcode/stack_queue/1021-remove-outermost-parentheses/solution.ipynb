# %% [markdown]
# # 1021 — Remove Outermost ParenthesesLink: https://leetcode.com/problems/remove-outermost-parentheses/## SummaryRemove the outermost parentheses from every primitive balanced substring in a parentheses string.

# %%
"""1021 — Remove Outermost Parentheses"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1021 — Remove Outermost Parentheses"""from __future__ import annotationsclass Solution:    pass```
