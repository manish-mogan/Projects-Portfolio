# %% [markdown]
# # 0674 — Longest Continuous Increasing SubsequenceLink: https://leetcode.com/problems/longest-continuous-increasing-subsequence/## SummaryFind the length of the longest contiguous strictly increasing segment in an array.

# %%
"""0674 — Longest Continuous Increasing Subsequence"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
