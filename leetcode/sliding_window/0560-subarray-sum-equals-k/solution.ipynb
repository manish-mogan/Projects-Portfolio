# %% [markdown]
# # 0560 — Subarray Sum Equals KLink: https://leetcode.com/problems/subarray-sum-equals-k/## SummaryCount how many contiguous subarrays sum to k.

# %%
"""0560 — Subarray Sum Equals K"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0560 — Subarray Sum Equals K"""from __future__ import annotationsclass Solution:    pass```
