# %% [markdown]
# # 0003 — Longest Substring Without Repeating CharactersLink: https://leetcode.com/problems/longest-substring-without-repeating-characters/## SummaryFind the length of the longest substring of a string that contains no repeated characters.

# %%
"""0003 — Longest Substring Without Repeating Characters"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0003 — Longest Substring Without Repeating Characters"""from __future__ import annotationsclass Solution:    pass```
