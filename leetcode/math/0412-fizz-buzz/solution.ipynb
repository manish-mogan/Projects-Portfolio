# %% [markdown]
# # 0412 — Fizz Buzz
#
# Link: https://leetcode.com/problems/fizz-buzz/
#
# ## Summary
# Produce the classic FizzBuzz list for numbers 1..n based on divisibility by 3 and 5.

# %%
"""0412 — Fizz Buzz"""

from __future__ import annotations


class Solution:
    pass
