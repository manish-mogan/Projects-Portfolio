# %% [markdown]
# # 1399 — Count Largest GroupLink: https://leetcode.com/problems/count-largest-group/## SummaryGroup numbers 1..n by the sum of their digits and return how many groups have the largest size.

# %%
"""1399 — Count Largest Group"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
