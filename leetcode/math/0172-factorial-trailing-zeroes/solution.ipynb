# %% [markdown]
# # 0172 — Factorial Trailing ZeroesLink: https://leetcode.com/problems/factorial-trailing-zeroes/## SummaryCompute how many trailing zeros are in n! by counting factors of 5.

# %%
"""0172 — Factorial Trailing Zeroes"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0172 — Factorial Trailing Zeroes"""from __future__ import annotationsclass Solution:    pass```
