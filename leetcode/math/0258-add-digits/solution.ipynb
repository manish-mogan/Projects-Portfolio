# %% [markdown]
# # 0258 — Add DigitsLink: https://leetcode.com/problems/add-digits/## SummaryRepeatedly sum the digits of a number until one digit remains and return it (digital root).

# %%
"""0258 — Add Digits"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0258 — Add Digits"""from __future__ import annotationsclass Solution:    pass```
