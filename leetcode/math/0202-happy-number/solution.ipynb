# %% [markdown]
# # 0202 — Happy NumberLink: https://leetcode.com/problems/happy-number/## SummaryRepeatedly replace a number by the sum of squares of its digits; determine if it eventually reaches 1.

# %%
"""0202 — Happy Number"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0202 — Happy Number"""from __future__ import annotationsclass Solution:    pass```
