# %% [markdown]
# # 1137 — N-th Tribonacci NumberLink: https://leetcode.com/problems/n-th-tribonacci-number/## SummaryCompute the n-th Tribonacci number with base values T0=0, T1=1, T2=1.

# %%
"""1137 — N-th Tribonacci Number"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""1137 — N-th Tribonacci Number"""from __future__ import annotationsclass Solution:    pass```
