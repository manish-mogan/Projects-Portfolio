# %% [markdown]
# # 1360 — Number of Days Between Two DatesLink: https://leetcode.com/problems/number-of-days-between-two-dates/## SummaryCompute the number of days between two dates given as YYYY-MM-DD.

# %%
"""1360 — Number of Days Between Two Dates"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
