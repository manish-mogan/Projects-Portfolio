# %% [markdown]
# # 1108 — Defanging an IP AddressLink: https://leetcode.com/problems/defanging-an-ip-address/## SummaryReplace '.' with '[.]' in an IP address string to produce a defanged version.

# %%
"""1108 — Defanging an IP Address"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
