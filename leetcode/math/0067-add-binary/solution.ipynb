# %% [markdown]
# # 0067 — Add BinaryLink: https://leetcode.com/problems/add-binary/## SummaryAdd two binary strings and return the sum as a binary string.

# %%
"""0067 — Add Binary"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
