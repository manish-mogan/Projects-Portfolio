# %% [markdown]
# # 0292 — Nim GameLink: https://leetcode.com/problems/nim-game/## SummaryGiven n stones where players remove 1–3 each turn, determine if the first player has a winning strategy.

# %%
"""0292 — Nim Game"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
