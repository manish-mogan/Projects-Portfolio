# %% [markdown]
# # 0292 — Nim Game
#
# Link: https://leetcode.com/problems/nim-game/
#
# ## Summary
# Given n stones where players remove 1–3 each turn, determine if the first player has a winning strategy.

# %%
"""0292 — Nim Game"""

from __future__ import annotations


class Solution:
    pass
