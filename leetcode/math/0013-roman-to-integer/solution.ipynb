# %% [markdown]
# # 0013 — Roman to IntegerLink: https://leetcode.com/problems/roman-to-integer/## SummaryConvert a Roman numeral string into its integer value, handling subtractive pairs correctly.

# %%
"""0013 — Roman to Integer"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0013 — Roman to Integer"""from __future__ import annotationsclass Solution:    pass```
