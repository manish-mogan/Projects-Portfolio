# %% [markdown]
# # 0066 — Plus OneLink: https://leetcode.com/problems/plus-one/## SummaryGiven a non-negative integer represented as an array of digits, add one and return the resulting digits.

# %%
"""0066 — Plus One"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0066 — Plus One"""from __future__ import annotationsclass Solution:    pass```
