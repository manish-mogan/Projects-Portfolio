# %% [markdown]
# # 1362 — Closest DivisorsLink: https://leetcode.com/problems/closest-divisors/## SummaryFind two integers whose product is n+1 or n+2 and whose absolute difference is minimized.

# %%
"""1362 — Closest Divisors"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
