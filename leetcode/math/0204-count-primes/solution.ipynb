# %% [markdown]
# # 0204 — Count PrimesLink: https://leetcode.com/problems/count-primes/## SummaryCount how many prime numbers are strictly less than n.

# %%
"""0204 — Count Primes"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution```python"""0204 — Count Primes"""from __future__ import annotationsclass Solution:    pass```
