# %% [markdown]
# # 0009 — Palindrome NumberLink: https://leetcode.com/problems/palindrome-number/## SummaryDetermine whether an integer reads the same forward and backward without converting it to a string (where possible).

# %%
"""0009 — Palindrome Number"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
