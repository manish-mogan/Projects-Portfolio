# %% [markdown]
# # 1401 — Circle and Rectangle OverlappingLink: https://leetcode.com/problems/circle-and-rectangle-overlapping/## SummaryDetermine whether a circle overlaps (intersects or touches) an axis-aligned rectangle on a 2D plane.

# %%
"""1401 — Circle and Rectangle Overlapping"""from __future__ import annotationsclass Solution:    pass

# %% [markdown]
# ## Solution**Complexity:**- Time: O(n)- Space: O(n)(Code is in the next cell; expand it to view.)

# %%
from __future__ import annotationsclass Solution:    pass```
